# %% [markdown]
# # Downloading required packages

# %%
library("BiocParallel")
register(MulticoreParam(4))
library("DESeq2")
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
# ...

# %% [markdown]
# ## Within line variance

# %% [markdown]
# ### CC2344

# %%
directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"

sampleFiles <- grep("_genes_count", list.files(directory), value=TRUE)
samples <- grep("CC2344", sampleFiles, value=TRUE)
fileNames <- sub("_genes_count", "", sampleFiles)
CC2344 <- grep("CC2344", fileNames, value=TRUE)

condition <- c('ANC', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'L10', 'L11', 'L12', 'L13', 'L14', 'L15')
sampleTable <- data.frame(sampleName = CC2344, fileName = samples, condition = 'treated', stringsAsFactors = FALSE)

for (i in condition) {
    sampleTable$condition[grep(i, sampleTable$fileName)] = i
    }
sampleTable$condition <- factor(sampleTable$condition)
sampleTable$condition <- relevel(sampleTable$condition, ref = 'ANC')

ddsHTSeq <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable, directory = directory, design= ~ condition)

# %%
sampleTable
write.csv(as.data.frame(sampleTable), file="gene_count_labels")
# Out:
#    sampleName          fileName                        condition
# 1  198.CC2344-L15-rep3 198.CC2344-L15-rep3_genes_count L15
# 2  239.CC2344-L7-rep3  239.CC2344-L7-rep3_genes_count  L7
# 3  240.CC2344-L15-rep2 240.CC2344-L15-rep2_genes_count L15
# 4  247.CC2344-ANC-rep1 247.CC2344-ANC-rep1_genes_count ANC
# 5  248.CC2344-ANC-rep2 248.CC2344-ANC-rep2_genes_count ANC
# 6  249.CC2344-ANC-rep3 249.CC2344-ANC-rep3_genes_count ANC
# 7  250.CC2344-L1-rep1  250.CC2344-L1-rep1_genes_count  L1
# 8  251.CC2344-L1-rep2  251.CC2344-L1-rep2_genes_count  L1
# 9  252.CC2344-L1-rep3  252.CC2344-L1-rep3_genes_count  L1
# 10 253.CC2344-L2-rep1  253.CC2344-L2-rep1_genes_count  L2
# 11 254.CC2344-L2-rep2  254.CC2344-L2-rep2_genes_count  L2
# 12 255.CC2344-L2-rep3  255.CC2344-L2-rep3_genes_count  L2
# 13 256.CC2344-L3-rep1  256.CC2344-L3-rep1_genes_count  L3
# 14 257.CC2344-L3-rep2  257.CC2344-L3-rep2_genes_count  L3
# 15 258.CC2344-L3-rep3  258.CC2344-L3-rep3_genes_count  L3
# ...

# %%
# #LIBRARY SIZE NORMALIZATION
# # (divide each column of counts(dds) by sizeFactor(dds))
# directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"
# dds <- estimateSizeFactors(ddsHTSeq)
# counts <- counts(dds, normalized=TRUE)
# write.table(counts, paste(directory, "_deseq_CC2344", ".txt", sep=""), sep="\t", quote = F)

# #Plot column sums according to size factor
# plot(sizeFactors(dds), colSums(counts(dds)))
# abline(lm(colSums(counts(dds)) ~ sizeFactors(dds) + 0))
# Out:
# plot without title

# %%
dds <- DESeq(ddsHTSeq, parallel = TRUE)
res_L1 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L1'), alpha = 0.05)
res_L2 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L2'), alpha = 0.05)
res_L3 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L3'), alpha = 0.05)
res_L4 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L4'), alpha = 0.05)
res_L5 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L5'), alpha = 0.05)
res_L6 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L6'), alpha = 0.05)
res_L7 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L7'), alpha = 0.05)
res_L8 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L8'), alpha = 0.05)
res_L9 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L9'), alpha = 0.05)
res_L10 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L10'), alpha = 0.05)
res_L11 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L11'), alpha = 0.05)
res_L12 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L12'), alpha = 0.05)
res_L13 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L13'), alpha = 0.05)
res_L14 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L14'), alpha = 0.05)
res_L15 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L15'), alpha = 0.05)

# # SUMMARY OF PROFILE
# resOrdered_L1 <- res_L1[order(res_L1$pvalue),]
# resOrdered_L2 <- res_L2[order(res_L2$pvalue),]
# resOrdered_L3 <- res_L3[order(res_L3$pvalue),]
# resOrdered_L4 <- res_L4[order(res_L4$pvalue),]
# resOrdered_L5 <- res_L5[order(res_L5$pvalue),]
# resOrdered_L6 <- res_L6[order(res_L6$pvalue),]
# resOrdered_L7 <- res_L7[order(res_L7$pvalue),]
# resOrdered_L8 <- res_L8[order(res_L8$pvalue),]
# resOrdered_L9 <- res_L9[order(res_L9$pvalue),]
# resOrdered_L10 <- res_L10[order(res_L10$pvalue),]
# resOrdered_L11 <- res_L11[order(res_L11$pvalue),]
# resOrdered_L12 <- res_L12[order(res_L12$pvalue),]
# resOrdered_L13 <- res_L13[order(res_L13$pvalue),]
# resOrdered_L14 <- res_L14[order(res_L14$pvalue),]
# resOrdered_L15 <- res_L15[order(res_L15$pvalue),]
# summary(resOrdered_L1)
# summary(resOrdered_L2)
# summary(resOrdered_L3)
# summary(resOrdered_L4)
# summary(resOrdered_L5)
# summary(resOrdered_L6)
# summary(resOrdered_L7)
# summary(resOrdered_L8)
# summary(resOrdered_L9)
# summary(resOrdered_L10)
# summary(resOrdered_L11)
# summary(resOrdered_L12)
# summary(resOrdered_L13)
# summary(resOrdered_L14)
# summary(resOrdered_L15)

# #LFC Shrinkage
# resLFC_L1 <- lfcShrink(dds, coef="condition_L1_vs_ANC", type="apeglm")
# resLFC_L2 <- lfcShrink(dds, coef="condition_L2_vs_ANC", type="apeglm")
# resLFC_L3 <- lfcShrink(dds, coef="condition_L3_vs_ANC", type="apeglm")
# resLFC_L4 <- lfcShrink(dds, coef="condition_L4_vs_ANC", type="apeglm")
# resLFC_L5 <- lfcShrink(dds, coef="condition_L5_vs_ANC", type="apeglm")
# resLFC_L6 <- lfcShrink(dds, coef="condition_L6_vs_ANC", type="apeglm")
# resLFC_L7 <- lfcShrink(dds, coef="condition_L7_vs_ANC", type="apeglm")
# resLFC_L8 <- lfcShrink(dds, coef="condition_L8_vs_ANC", type="apeglm")
# resLFC_L9 <- lfcShrink(dds, coef="condition_L9_vs_ANC", type="apeglm")
# resLFC_L10 <- lfcShrink(dds, coef="condition_L10_vs_ANC", type="apeglm")
# resLFC_L11 <- lfcShrink(dds, coef="condition_L11_vs_ANC", type="apeglm")
# resLFC_L12 <- lfcShrink(dds, coef="condition_L12_vs_ANC", type="apeglm")
# resLFC_L13 <- lfcShrink(dds, coef="condition_L13_vs_ANC", type="apeglm")
# resLFC_L14 <- lfcShrink(dds, coef="condition_L14_vs_ANC", type="apeglm")
# resLFC_L15 <- lfcShrink(dds, coef="condition_L15_vs_ANC", type="apeglm")

# #File of differentially expressed genes
# resSig_L1 = resOrdered_L1[which(resOrdered_L1$padj < 0.05),]
# resSig_L2 = resOrdered_L2[which(resOrdered_L2$padj < 0.05),]
# resSig_L3 = resOrdered_L3[which(resOrdered_L3$padj < 0.05),]
# resSig_L4 = resOrdered_L4[which(resOrdered_L4$padj < 0.05),]
# resSig_L5 = resOrdered_L5[which(resOrdered_L5$padj < 0.05),]
# resSig_L6 = resOrdered_L6[which(resOrdered_L6$padj < 0.05),]
# resSig_L7 = resOrdered_L7[which(resOrdered_L7$padj < 0.05),]
# resSig_L8 = resOrdered_L8[which(resOrdered_L8$padj < 0.05),]
# resSig_L9 = resOrdered_L9[which(resOrdered_L9$padj < 0.05),]
# resSig_L10 = resOrdered_L10[which(resOrdered_L10$padj < 0.05),]
# resSig_L11 = resOrdered_L11[which(resOrdered_L11$padj < 0.05),]
# resSig_L12 = resOrdered_L12[which(resOrdered_L12$padj < 0.05),]
# resSig_L13 = resOrdered_L13[which(resOrdered_L13$padj < 0.05),]
# resSig_L14 = resOrdered_L14[which(resOrdered_L14$padj < 0.05),]
# resSig_L15 = resOrdered_L15[which(resOrdered_L15$padj < 0.05),]
# summary(resSig_L1)
# summary(resSig_L2)
# summary(resSig_L3)
# summary(resSig_L4)
# summary(resSig_L5)
# summary(resSig_L6)
# summary(resSig_L7)
# summary(resSig_L8)
# summary(resSig_L9)
# summary(resSig_L10)
# summary(resSig_L11)
# summary(resSig_L12)
# summary(resSig_L13)
# summary(resSig_L14)
# summary(resSig_L15)

# #PLOTS
# plotMA(res_L1, ylim=c(-5,5))
# plotMA(resLFC_L1, ylim=c(-5,5))
# plotMA(res_L2, ylim=c(-5,5))
# plotMA(resLFC_L2, ylim=c(-5,5))
# plotMA(res_L3, ylim=c(-5,5))
# plotMA(resLFC_L3, ylim=c(-5,5))
# plotMA(res_L4, ylim=c(-5,5))
# plotMA(resLFC_L4, ylim=c(-5,5))
# plotMA(res_L5, ylim=c(-5,5))
# plotMA(resLFC_L5, ylim=c(-5,5))
# plotMA(res_L6, ylim=c(-5,5))
# plotMA(resLFC_L6, ylim=c(-5,5))
# plotMA(res_L7, ylim=c(-5,5))
# plotMA(resLFC_L7, ylim=c(-5,5))
# plotMA(res_L8, ylim=c(-5,5))
# plotMA(resLFC_L8, ylim=c(-5,5))
# plotMA(res_L9, ylim=c(-5,5))
# plotMA(resLFC_L9, ylim=c(-5,5))
# plotMA(res_L10, ylim=c(-5,5))
# plotMA(resLFC_L10, ylim=c(-5,5))
# plotMA(res_L11, ylim=c(-5,5))
# plotMA(resLFC_L11, ylim=c(-5,5))
# plotMA(res_L12, ylim=c(-5,5))
# plotMA(resLFC_L12, ylim=c(-5,5))
# plotMA(res_L13, ylim=c(-5,5))
# plotMA(resLFC_L13, ylim=c(-5,5))
# plotMA(res_L14, ylim=c(-5,5))
# plotMA(resLFC_L14, ylim=c(-5,5))
# plotMA(res_L15, ylim=c(-5,5))
# plotMA(resLFC_L15, ylim=c(-5,5))
# abline(h=c(-1,1), col="dodgerblue", lwd=2)

#File of differentially expressed genes

# write.csv(as.data.frame(resSig_L1), file="CC2344.resSig_L1.genes")
# write.csv(as.data.frame(resSig_L2), file="CC2344.resSig_L2.genes")
# write.csv(as.data.frame(resSig_L3), file="CC2344.resSig_L3.genes")
# write.csv(as.data.frame(resSig_L4), file="CC2344.resSig_L4.genes")
# write.csv(as.data.frame(resSig_L5), file="CC2344.resSig_L5.genes")
# write.csv(as.data.frame(resSig_L6), file="CC2344.resSig_L6.genes")
# write.csv(as.data.frame(resSig_L7), file="CC2344.resSig_L7.genes")
# write.csv(as.data.frame(resSig_L8), file="CC2344.resSig_L8.genes")
# write.csv(as.data.frame(resSig_L9), file="CC2344.resSig_L9.genes")
# write.csv(as.data.frame(resSig_L10), file="CC2344.resSig_L10.genes")
# write.csv(as.data.frame(resSig_L11), file="CC2344.resSig_L11.genes")
# write.csv(as.data.frame(resSig_L12), file="CC2344.resSig_L12.genes")
# write.csv(as.data.frame(resSig_L13), file="CC2344.resSig_L13.genes")
# write.csv(as.data.frame(resSig_L14), file="CC2344.resSig_L14.genes")
# write.csv(as.data.frame(resSig_L15), file="CC2344.resSig_L15.genes")

# # #PCA PLOT
# # vsdata <- vst(dds, blind=FALSE)
# # plotPCA(vsdata, intgroup="condition")
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates: 4 workers
#
# mean-dispersion relationship
#
# final dispersion estimates, fitting model and testing: 4 workers

# %%
# EXPORTING RESULTS

write.table(as.data.frame(res_L1), 'CC2344-L1',  sep="\t", quote = F)
write.table(as.data.frame(res_L2), 'CC2344-L2',  sep="\t", quote = F)
write.table(as.data.frame(res_L3), 'CC2344-L3',  sep="\t", quote = F)
write.table(as.data.frame(res_L4), 'CC2344-L4',  sep="\t", quote = F)
write.table(as.data.frame(res_L5), 'CC2344-L5',  sep="\t", quote = F)
write.table(as.data.frame(res_L6), 'CC2344-L6',  sep="\t", quote = F)
write.table(as.data.frame(res_L7), 'CC2344-L7',  sep="\t", quote = F)
write.table(as.data.frame(res_L8), 'CC2344-L8',  sep="\t", quote = F)
write.table(as.data.frame(res_L9), 'CC2344-L9',  sep="\t", quote = F)
write.table(as.data.frame(res_L10), 'CC2344-L10',  sep="\t", quote = F)
write.table(as.data.frame(res_L11), 'CC2344-L11',  sep="\t", quote = F)
write.table(as.data.frame(res_L12), 'CC2344-L12',  sep="\t", quote = F)
write.table(as.data.frame(res_L13), 'CC2344-L13',  sep="\t", quote = F)
write.table(as.data.frame(res_L14), 'CC2344-L14',  sep="\t", quote = F)
write.table(as.data.frame(res_L15), 'CC2344-L15',  sep="\t", quote = F)

# %% [markdown]
# ### CC2931

# %%
directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"

sampleFiles <- grep("_genes_count", list.files(directory), value=TRUE)
samples <- grep("CC2931", sampleFiles, value=TRUE)
fileNames <- sub("_genes_count", "", sampleFiles)
CC2931 <- grep("CC2931", fileNames, value=TRUE) 

condition <- c('ANC', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L9', 'L10', 'L11', 'L13', 'L14', 'L15')
sampleTable <- data.frame(sampleName = CC2931, fileName = samples, condition = 'treated', stringsAsFactors = FALSE)

for (i in condition) {
    sampleTable$condition[grep(i, sampleTable$fileName)] = i
    }
sampleTable$condition <- factor(sampleTable$condition)
sampleTable$condition <- relevel(sampleTable$condition, ref = 'ANC')

ddsHTSeq <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable, directory = directory, design= ~ condition)

# %%
# #LIBRARY SIZE NORMALIZATION
# # (divide each column of counts(dds) by sizeFactor(dds))
# directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"
# dds <- estimateSizeFactors(ddsHTSeq)
# counts <- counts(dds, normalized=TRUE)
# write.table(counts, paste(directory, "_deseq_CC2931", ".txt", sep=""), sep="\t", quote = F)

# #Plot column sums according to size factor
# plot(sizeFactors(dds), colSums(counts(dds)))
# abline(lm(colSums(counts(dds)) ~ sizeFactors(dds) + 0))
# Out:
# plot without title

# %%
dds <- DESeq(ddsHTSeq, parallel = TRUE)
res_L1 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L1'), alpha = 0.05)
res_L2 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L2'), alpha = 0.05)
res_L3 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L3'), alpha = 0.05)
res_L4 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L4'), alpha = 0.05)
res_L5 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L5'), alpha = 0.05)
res_L6 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L6'), alpha = 0.05)
res_L7 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L7'), alpha = 0.05)
res_L9 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L9'), alpha = 0.05)
res_L10 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L10'), alpha = 0.05)
res_L11 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L11'), alpha = 0.05)
res_L13 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L13'), alpha = 0.05)
res_L14 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L14'), alpha = 0.05)
res_L15 <- results(dds, pAdjustMethod = "BH", contrast = c('condition', 'ANC','L15'), alpha = 0.05)

# SUMMARY OF PROFILE
resOrdered_L1 <- res_L1[order(res_L1$pvalue),]
resOrdered_L2 <- res_L2[order(res_L2$pvalue),]
resOrdered_L3 <- res_L3[order(res_L3$pvalue),]
resOrdered_L4 <- res_L4[order(res_L4$pvalue),]
resOrdered_L5 <- res_L5[order(res_L5$pvalue),]
resOrdered_L6 <- res_L6[order(res_L6$pvalue),]
resOrdered_L7 <- res_L7[order(res_L7$pvalue),]
resOrdered_L9 <- res_L9[order(res_L9$pvalue),]
resOrdered_L10 <- res_L10[order(res_L10$pvalue),]
resOrdered_L11 <- res_L11[order(res_L11$pvalue),]
resOrdered_L13 <- res_L13[order(res_L13$pvalue),]
resOrdered_L14 <- res_L14[order(res_L14$pvalue),]
resOrdered_L15 <- res_L15[order(res_L15$pvalue),]
# summary(resOrdered_L1)
# summary(resOrdered_L2)
# summary(resOrdered_L3)
# summary(resOrdered_L4)
# summary(resOrdered_L5)
# summary(resOrdered_L6)
# summary(resOrdered_L7)
# summary(resOrdered_L9)
# summary(resOrdered_L10)
# summary(resOrdered_L11)
# summary(resOrdered_L13)
# summary(resOrdered_L14)
# summary(resOrdered_L15)

# #LFC Shrinkage
# resLFC_L1 <- lfcShrink(dds, coef="condition_L1_vs_ANC", type="apeglm")
# resLFC_L2 <- lfcShrink(dds, coef="condition_L2_vs_ANC", type="apeglm")
# resLFC_L3 <- lfcShrink(dds, coef="condition_L3_vs_ANC", type="apeglm")
# resLFC_L4 <- lfcShrink(dds, coef="condition_L4_vs_ANC", type="apeglm")
# resLFC_L5 <- lfcShrink(dds, coef="condition_L5_vs_ANC", type="apeglm")
# resLFC_L6 <- lfcShrink(dds, coef="condition_L6_vs_ANC", type="apeglm")
# resLFC_L7 <- lfcShrink(dds, coef="condition_L7_vs_ANC", type="apeglm")
# resLFC_L9 <- lfcShrink(dds, coef="condition_L9_vs_ANC", type="apeglm")
# resLFC_L10 <- lfcShrink(dds, coef="condition_L10_vs_ANC", type="apeglm")
# resLFC_L11 <- lfcShrink(dds, coef="condition_L11_vs_ANC", type="apeglm")
# resLFC_L13 <- lfcShrink(dds, coef="condition_L13_vs_ANC", type="apeglm")
# resLFC_L14 <- lfcShrink(dds, coef="condition_L14_vs_ANC", type="apeglm")
# resLFC_L15 <- lfcShrink(dds, coef="condition_L15_vs_ANC", type="apeglm")

#File of differentially expressed genes
resSig_L1 = resOrdered_L1[which(resOrdered_L1$padj < 0.05),]
resSig_L2 = resOrdered_L2[which(resOrdered_L2$padj < 0.05),]
resSig_L3 = resOrdered_L3[which(resOrdered_L3$padj < 0.05),]
resSig_L4 = resOrdered_L4[which(resOrdered_L4$padj < 0.05),]
resSig_L5 = resOrdered_L5[which(resOrdered_L5$padj < 0.05),]
resSig_L6 = resOrdered_L6[which(resOrdered_L6$padj < 0.05),]
resSig_L7 = resOrdered_L7[which(resOrdered_L7$padj < 0.05),]
resSig_L9 = resOrdered_L9[which(resOrdered_L9$padj < 0.05),]
resSig_L10 = resOrdered_L10[which(resOrdered_L10$padj < 0.05),]
resSig_L11 = resOrdered_L11[which(resOrdered_L11$padj < 0.05),]
resSig_L13 = resOrdered_L13[which(resOrdered_L13$padj < 0.05),]
resSig_L14 = resOrdered_L14[which(resOrdered_L14$padj < 0.05),]
resSig_L15 = resOrdered_L15[which(resOrdered_L15$padj < 0.05),]
summary(resSig_L1)
summary(resSig_L2)
summary(resSig_L3)
summary(resSig_L4)
summary(resSig_L5)
summary(resSig_L6)
summary(resSig_L7)
summary(resSig_L9)
summary(resSig_L10)
summary(resSig_L11)
summary(resSig_L13)
summary(resSig_L14)
summary(resSig_L15)

# #PLOTS
# plotMA(res_L1, ylim=c(-5,5))
# plotMA(resLFC_L1, ylim=c(-5,5))
# plotMA(res_L2, ylim=c(-5,5))
# plotMA(resLFC_L2, ylim=c(-5,5))
# plotMA(res_L3, ylim=c(-5,5))
# plotMA(resLFC_L3, ylim=c(-5,5))
# plotMA(res_L4, ylim=c(-5,5))
# plotMA(resLFC_L4, ylim=c(-5,5))
# plotMA(res_L5, ylim=c(-5,5))
# plotMA(resLFC_L5, ylim=c(-5,5))
# plotMA(res_L6, ylim=c(-5,5))
# plotMA(resLFC_L6, ylim=c(-5,5))
# plotMA(res_L7, ylim=c(-5,5))
# plotMA(resLFC_L7, ylim=c(-5,5))
# plotMA(res_L9, ylim=c(-5,5))
# plotMA(resLFC_L9, ylim=c(-5,5))
# plotMA(res_L10, ylim=c(-5,5))
# plotMA(resLFC_L10, ylim=c(-5,5))
# plotMA(res_L11, ylim=c(-5,5))
# plotMA(resLFC_L11, ylim=c(-5,5))
# plotMA(res_L13, ylim=c(-5,5))
# plotMA(resLFC_L13, ylim=c(-5,5))
# plotMA(res_L14, ylim=c(-5,5))
# plotMA(resLFC_L14, ylim=c(-5,5))
# plotMA(res_L15, ylim=c(-5,5))
# plotMA(resLFC_L15, ylim=c(-5,5))
# abline(h=c(-1,1), col="dodgerblue", lwd=2)

# #File of differentially expressed genes
# write.csv(as.data.frame(resSig_L1), file="CC2931.resSig_L1.genes")
# write.csv(as.data.frame(resSig_L2), file="CC2931.resSig_L2.genes")
# write.csv(as.data.frame(resSig_L3), file="CC2931.resSig_L3.genes")
# write.csv(as.data.frame(resSig_L4), file="CC2931.resSig_L4.genes")
# write.csv(as.data.frame(resSig_L5), file="CC2931.resSig_L5.genes")
# write.csv(as.data.frame(resSig_L6), file="CC2931.resSig_L6.genes")
# write.csv(as.data.frame(resSig_L7), file="CC2931.resSig_L7.genes")
# write.csv(as.data.frame(resSig_L8), file="CC2931.resSig_L8.genes")
# write.csv(as.data.frame(resSig_L9), file="CC2931.resSig_L9.genes")
# write.csv(as.data.frame(resSig_L10), file="CC2931.resSig_L10.genes")
# write.csv(as.data.frame(resSig_L11), file="CC2931.resSig_L11.genes")
# write.csv(as.data.frame(resSig_L12), file="CC2931.resSig_L12.genes")
# write.csv(as.data.frame(resSig_L13), file="CC2931.resSig_L13.genes")
# write.csv(as.data.frame(resSig_L14), file="CC2931.resSig_L14.genes")
# write.csv(as.data.frame(resSig_L15), file="CC2931.resSig_L15.genes")

# # #PCA PLOT
# # vsdata <- vst(dds, blind=FALSE)
# # plotPCA(vsdata, intgroup="condition")
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates: 4 workers
#
# mean-dispersion relationship
#
# final dispersion estimates, fitting model and testing: 4 workers
# out of 1464 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 623, 43%
# LFC < 0 (down)     : 841, 57%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 1)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
#
# out of 536 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 221, 41%
# LFC < 0 (down)     : 315, 59%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 1)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
#
# out of 349 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 139, 40%
# LFC < 0 (down)     : 210, 60%
# outliers [1]       : 0, 0%
# ...

# %%
# # EXPORTING RESULTS
write.table(as.data.frame(res_L1), 'CC2931-L1',  sep="\t", quote = F)
write.table(as.data.frame(res_L2), 'CC2931-L2',  sep="\t", quote = F)
write.table(as.data.frame(res_L3), 'CC2931-L3',  sep="\t", quote = F)
write.table(as.data.frame(res_L4), 'CC2931-L4',  sep="\t", quote = F)
write.table(as.data.frame(res_L5), 'CC2931-L5',  sep="\t", quote = F)
write.table(as.data.frame(res_L6), 'CC2931-L6',  sep="\t", quote = F)
write.table(as.data.frame(res_L7), 'CC2931-L7',  sep="\t", quote = F)
write.table(as.data.frame(res_L9), 'CC2931-L9',  sep="\t", quote = F)
write.table(as.data.frame(res_L10), 'CC2931-L10',  sep="\t", quote = F)
write.table(as.data.frame(res_L11), 'CC2931-L11',  sep="\t", quote = F)
write.table(as.data.frame(res_L13), 'CC2931-L13',  sep="\t", quote = F)
write.table(as.data.frame(res_L14), 'CC2931-L14',  sep="\t", quote = F)
write.table(as.data.frame(res_L15), 'CC2931-L15',  sep="\t", quote = F)

# %%
plotCounts(dds, gene="ChCC-v11030321m.g", intgroup="condition")
par(mar=c(8,5,2,2))

# # Count outliers - Cook's distance
# boxplot(log10(assays(dds)[["cooks"]]), range=0, las=2)
# # (Boxplot of the Cook’s distances to see if one sample is consistently higher than others)
# Out:
# plot without title

# %% [markdown]
# ## Differential Expression Analysis

# %%
directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"

sampleFiles <- grep("_genes_count", list.files(directory), value=TRUE)
fileNames <- sub("_genes_count", "", sampleFiles)
sampleTable <- data.frame(sampleName = fileNames, fileName = sampleFiles, condition = "treated", stringsAsFactors = FALSE)
sampleTable$condition[grep("ANC", sampleTable$fileName)] = "control"
sampleTable$condition <- factor(sampleTable$condition)

ddsHTSeq <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable, directory = directory, design= ~ condition)

# # Setting the base level as control
# colData(ddsHTSeq)$protocol <- relevel(colData(ddsHTSeq)$protocol, "control")
# levels(colData(ddsHTSeq)$protocol)

# %%
# #LIBRARY SIZE NORMALIZATION
# # (divide each column of counts(dds) by sizeFactor(dds))
# directory <- "/research/projects/chlamydomonas/MAexpression/data/gene_count"
# dds <- estimateSizeFactors(ddsHTSeq)
# counts <- counts(dds, normalized=TRUE)
# write.table(counts, paste(directory, "_deseq_ALLSAM", ".txt", sep=""), sep="\t", quote = F)

# unnormalized_counts <- counts(ddsHTSeq)
# unnormalized_counts

# %% [markdown]
# ## Cluster Profiler

# %%
library('clusterProfiler')
library('enrichplot')
library('ggplot2')
library('GO.db')
# Out:
# clusterProfiler v3.18.1  For help: https://guangchuangyu.github.io/software/clusterProfiler
#
# If you use clusterProfiler in published research, please cite:
# Guangchuang Yu, Li-Gen Wang, Yanyan Han, Qing-Yu He. clusterProfiler: an R package for comparing biological themes among gene clusters. OMICS: A Journal of Integrative Biology. 2012, 16(5):284-287.
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
# ...

# %%
# reading in data from deseq2
df = read.csv("CC2931.resSig_L15.genes", header=TRUE)
# we want the log2 fold change 
original_gene_list <- df$log2FoldChange

# name the vector
names(original_gene_list) <- df$X

# omit any NA values 
gene_list<-na.omit(original_gene_list)

# sort the list in decreasing order (required for clusterProfiler)
gene_list = sort(gene_list, decreasing = TRUE)

# %%
kk <- enrichKEGG(gene         = gene_list,
                 organism     = 'cre',
                 pvalueCutoff = 0.05)

# %%
gse <- gseGO(geneList=gene_list, 
             ont ="ALL", 
             keyType = "GO", 
             nPerm = 10000, 
             minGSSize = 3, 
             maxGSSize = 800, 
             pvalueCutoff = 0.05, 
             verbose = TRUE, 
             OrgDb = get("org.Creinhardtii.eg.db"), 
             pAdjustMethod = "none")

# %%
require(DOSE)
dotplot(gse, showCategory=10, split=".sign", orderBy = 'x') + facet_grid(.~.sign)
# Out:
# plot without title

# %%
ids <- bitr(names(original_gene_list), fromType = "ENSEMBL", toType = "ENTREZID", OrgDb=organism)

# remove duplicate IDS (here I use "ENSEMBL", but it should be whatever was selected as keyType)
dedup_ids = ids[!duplicated(ids[c("ENSEMBL")]),]

# Create a new dataframe df2 which has only the genes which were successfully mapped using the bitr function above
df2 = df[df$X %in% dedup_ids$ENSEMBL,]

# Create a new column in df2 with the corresponding ENTREZ IDs
df2$Y = dedup_ids$ENTREZID

# Create a vector of the gene unuiverse
kegg_gene_list <- df2$log2FoldChange

# Name vector with ENTREZ ids
names(kegg_gene_list) <- df2$Y

# omit any NA values 
kegg_gene_list<-na.omit(kegg_gene_list)

# sort the list in decreasing order (required for clusterProfiler)
kegg_gene_list = sort(kegg_gene_list, decreasing = TRUE)

# %%
enrichKEGG(gene = gene_list, organism = "cre", keyType = "kegg", pvalueCutoff = 0.05, pAdjustMethod = "BH", universe, minGSSize = 3, maxGSSize = 2000, qvalueCutoff = 0.2, use_internal_data = FALSE)

# %% [markdown]
# ## Creating Chlamy Annotation Package

# %%
library('RSQLite')
library('AnnotationForge')

GO <- read.csv("/research/projects/chlamydomonas/MAexpression/data/genome_info/TOTAL_ANN.txt", sep = '\t', header = TRUE)

makeOrgPackage(gene_info=fSym, chromosome=fChr, go=fGO,
               version="0.1",
               maintainer="Some One <so@someplace.org>",
               author="Some One <so@someplace.org>",
               outputDir = ".",
               tax_id="59729",
               genus="Taeniopygia",
               species="guttata",
               goTable="go")
# Out:
#   ALIASES CHR           GENEID  SYMBOL
# 1 NaN     Cre08.g367500 5739187 LHCSR3.1
# 2 NaN     Cre08.g367400 5739187 LHCSR3.2
# 3 NaN     NaN           5739187 psaB
# 4 NaN     NaN           5739187 CAH1
# 5 NaN     NaN           5739187 psbA
# 6 NaN     NaN           5739187 rbcL
#   PROTEIN
# 1 Light-harvesting complex stress-related protein 3.1, chloroplastic (Chlorophyll a-b binding protein LHCSR3.1)
# 2 Light-harvesting complex stress-related protein 3.2, chloroplastic (Chlorophyll a-b binding protein LHCSR3.2)
# 3 Photosystem I P700 chlorophyll a apoprotein A2 (EC 1.97.1.12) (PSI-B) (PsaB)
# 4 Carbonic anhydrase 1 (EC 4.2.1.1) (Carbonate dehydratase 1) (CA1) [Cleaved into: Carbonic anhydrase 1 large chain; Carbonic anhydrase 1 small chain]
# 5 Photosystem II protein D1 (PSII D1 protein) (EC 1.10.3.9) (32 kDa thylakoid membrane protein) (Photosystem II Q(B) protein)
# 6 Ribulose bisphosphate carboxylase large chain (RuBisCO large subunit) (EC 4.1.1.39)
# ...

# %%
# library('AnnotationForge')
# makeOrgPackageFromNCBI(version = '5.6', author = 'Eni <eni.balogun@mail.utoronto.ca>', maintainer = 'Eni <eni.balogun@mail.utoronto.ca>',
# outputDir = '.', tax_id = '3055', genus = 'chlamydomonas', species = 'reinhardtii')
# Out:
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
# ...

# %%
install.packages('./org.Creinhardtii.eg.db', repos = NULL)
library('org.Creinhardtii.eg.db')
get('org.Creinhardtii.eg.db')
keytypes(org.Creinhardtii.eg.db)
# Out:
# Please see: help('select') for usage information
# OrgDb object:
# | DBSCHEMAVERSION: 2.1
# | DBSCHEMA: NOSCHEMA_DB
# | ORGANISM: chlamydomonas reinhardtii
# | SPECIES: chlamydomonas reinhardtii
# | CENTRALID: GID
# | Taxonomy ID: 3055
# | Db type: OrgDb
# | Supporting package: AnnotationDbi
#  [1] "ACCNUM"      "ALIAS"       "ENTREZID"    "EVIDENCE"    "EVIDENCEALL"
#  [6] "GENENAME"    "GID"         "GO"          "GOALL"       "ONTOLOGY"
# [11] "ONTOLOGYALL" "PMID"        "REFSEQ"      "SYMBOL"      "UNIGENE"
